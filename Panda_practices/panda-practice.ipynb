# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series

# %%
mydata = ['Boat','Car','Bike','Truck']
myseries1 = pd.Series(mydata)

# %%
print(myseries1)

# %%
mydata = [1,55,99,43]
myseries2 = pd.Series(mydata)
print(myseries2)

# %% [markdown]
# ## DataFrame

# %%
mydfdata = [('Boat',1),('Car',55),('Bike',99),('Truck',43)]
mydf = pd.DataFrame(mydfdata,columns=['thing','count'])
mydf

# %%
mydf['thing']

# %%
mydf.dtypes

# %% [markdown]
# # Reading in Data

# %%
df = pd.read_csv('../input/mrbeastyoutubevideostatistics/MrBeast_youtube_stats.csv')

# %% [markdown]
# # Inspect the Data

# %%
df.head()

# %%
df.dtypes

# %%
df.describe()

# %% [markdown]
# # Columns and Rows

# %%
df = df.set_index('id')

# %% [markdown]
# # Subsetting Data

# %%
df.columns

# %%
df = df[['title', 'description', 'publishTime', 'duration_seconds', 'viewCount',
       'likeCount','commentCount']]

# %%
df.shape

# %% [markdown]
# # Subsetting data

# %%
# Subsetting using loc
df_subset1 = df.loc[df['viewCount'] > 1_000_000]

# %%
df_subset2 = df.query('viewCount>1000000')

# %%
df = df.loc[~df['viewCount'].isna()]

# %% [markdown]
# # Casting dtypes

# %%
df['viewCount'] = df['viewCount'].astype('int')
df['likeCount'] = df['likeCount'].astype('int')

# %%
pd.to_datetime(df['publishTime'])

# %%
df['likeCount'] = pd.to_numeric(df['likeCount'].astype('str'))

# %% [markdown]
# # Creating new columns

# %%
df['like_to_view_ratio'] = df['likeCount'] / df['viewCount']

# %% [markdown]
# # Adding new Row

# %%
df_to_append = df.tail(1)

# %%
df_concat = pd.concat([df, df_to_append])

# %% [markdown]
# # Plot Examples

# %%
df['viewCount'].plot(kind='hist',bins=50,title='Distribution of View Count',
                    figsize=(15,5))

# %%
df.plot(kind='scatter',x='viewCount',y='likeCount', title='View vs Like Count')

# %%
df.query('likeCount>1000000')

# %% [markdown]
# # Save our output

# %%
df.to_csv('processed1_data.csv', index=False)
